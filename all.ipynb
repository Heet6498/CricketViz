# %%
import bs4 , requests, re
import numpy as np
import pandas as pd
import datetime
import csv

# %%
today = str(datetime.datetime.now())[0:10]

# %%
class cricScrap():
    def __init__(self, min_page, max_page, scraped_date):
        self.scraped_date = scraped_date
        self.min_page = min_page
        self.max_page = max_page
        
        self.urls = self.generate_urls()
        self.soups = self.getHTML()
        self.cric_table = self.getCricData()
        
    def generate_urls(self):
        urls = []
        for i in range(self.min_page, self.max_page + 1):
            urls.append('https://stats.espncricinfo.com/ci/engine/stats/index.html?class=2;home_or_away=1;home_or_away=2;home_or_away=3;template=results;type=team;view=results'.format(i))
        return urls
    
    def getHTML(self):
        soups = {}
        for url in self.urls:
            res = requests.get(url)
            soups[url] = bs4.BeautifulSoup(res.text)
        return soups
    def getCricData(self):
        fin_df = []
        for url, soup in self.soups.items():
            cric_vals = [x.text.split() for x in soup.find_all('tr', {'class' : 'data1'})]
            dfs = []
            for d in cric_vals:
                if len(d) == 10:
                    df_data = {
                    'team' : d[0],
                    'result' : d[1],
                    'margin' : np.nan,
                    'br' : np.nan,
                    'toss' : d[2],
                    'bat' : d[3],
                    'opposition' : d[5],
                    'ground' : d[6],
                    'date' : d[-1],
                    'url' : url,
                    'scrapped_date' : today
                }
                    df = pd.DataFrame([df_data])
                    dfs.append(df)
                    
                if len(d) == 12:
                    df_data = [{
                    'team' : d[0],
                    'result' : d[1],
                    'margin' : ' '.join(d[2:4]),
                    'br' : np.nan,
                    'toss' : d[4],
                    'bat' : d[5],
                    'opposition' :d[7],
                    'ground' : d[8],
                    'date' : d[-1],
                    'url' : url,
                    'scrapped_date' : today
                }]
                    df = pd.DataFrame(df_data)
                    dfs.append(df)

                if len(d) == 14:
                    df_data = [{
                    'team' : d[0],
                    'result' : d[1],
                    'margin' : ' '.join(d[2:4]),
                    'br' : d[4],
                    'toss' : d[5],
                    'bat' : d[6],
                    'opposition' : ' '.join(d[8:10]),
                    'ground' : d[-4],
                    'date' : d[-1],
                    'url' : url,
                    'scrapped_date' : today
                }]
                    df = pd.DataFrame(df_data)
                    dfs.append(df)
                    
                if len(d) == 15:
                    df_data = [{
                    'team' : d[0],
                    'result' : d[1],
                    'margin' : ' '.join(d[2:4]),
                    'br' : d[4],
                    'toss' : d[5],
                    'bat' : d[6],
                    'opposition' : ' '.join(d[8:10]),
                    'ground' : d[-4],
                    'date' : d[-1],
                    'url' : url,
                    'scrapped_date' : today
                }]
                    df = pd.DataFrame(df_data)
                    dfs.append(df)

                if len(d) == 13:
                    df_data = [{
                    'team' : d[0],
                    'result' : d[1],
                    'margin' : ' '.join(d[2:4]),
                    'br' : d[4],
                    'toss' : d[4],
                    'bat' : d[5],
                    'opposition' : ' '.join(d[8:9]),
                    'ground' : d[-4],
                    'date' : d[-1],
                    'url' : url,
                    'scrapped_date' : today
                }]
                    df = pd.DataFrame(df_data)
                    dfs.append(df)
            fin_df.append(pd.concat(dfs))
        return pd.concat(fin_df)

# %%
# %time cric = cricScrap(min_page = 1, max_page = 178, scraped_date=today)
# Out:
# Wall time: 4min 37s

# %%
cric.cric_table
# Out:
#         team   result      margin       br  toss   bat     opposition  \
# 0  Australia      won   5 wickets       42    42   won        England
# 0    England     lost   5 wickets       42    42  lost      Australia
# 0    England      won   6 wickets       35    35  lost      Australia
# 0  Australia     lost   6 wickets       35    35   won        England
# 0  Australia      won   5 wickets       21    21   won        England
# 0    England     lost   5 wickets       21    21  lost      Australia
# 0    England      won   2 wickets       21    21   won      Australia
# 0  Australia     lost   2 wickets       21    21  lost        England
# 0        New  Zealand      won 22     runs  runs  lost       Pakistan
# 0   Pakistan     lost     22 runs      won   won   2nd        Zealand
# 0    England      won   7 wickets       57  lost   2nd    New Zealand
# 0        New  Zealand      lost 7  wickets    57   won      v England
# 0    England      n/r      - lost      NaN   1st     v        Zealand
# 0        New  Zealand       n/r -      NaN   won   2nd        England
# 0    England      won   1 wickets        3  lost   2nd    West Indies
# 0       West   Indies      lost 1  wickets     3   won      v England
# 0       West   Indies       won 8  wickets    76  lost      v England
# 0    England     lost   8 wickets       76   won   1st    West Indies
# 0  Australia      won   7 wickets       85  lost   2nd    New Zealand
# 0        New  Zealand      lost 7  wickets    85   won    v Australia
# 0  Australia      won     31 runs      won   won   1st        Zealand
# 0        New  Zealand     lost 31     runs  runs  lost      Australia
# 0    England      won   4 wickets       23    23   won          India
# 0      India     lost   4 wickets       23    23  lost        England
# 0    England      won   6 wickets       37  lost   2nd      India The
# 0      India     lost   6 wickets       37   won   1st    England The
# 0   Pakistan      won   7 wickets       43    43  lost        England
# 0    England     lost   7 wickets       43    43   won       Pakistan
# 0   Pakistan      won   8 wickets      102   102   won        England
# 0    England     lost   8 wickets      102   102  lost       Pakistan
# 0    England      won   3 wickets       23    23   won      Australia
# 0  Australia     lost   3 wickets       23    23  lost        England
# 0    England      n/r      - lost      NaN   1st     v        Zealand
# 0        New  Zealand       n/r -      NaN   won   2nd        England
# 0    England      n/r      - lost      NaN   2nd     v        Zealand
# 0        New  Zealand       n/r -      NaN   won   1st        England
# 0    England      won    202 runs      NaN   won   1st          India
# 0      India     lost    202 runs      NaN  lost   2nd        England
# 0        New  Zealand     won 181     runs   won   1st    East Africa
# 0       East   Africa    lost 181     runs  lost   2nd    New Zealand
# 0  Australia      won     73 runs      NaN   won   1st       Pakistan
# 0   Pakistan     lost     73 runs      NaN  lost   2nd      Australia
# 0       West   Indies       won 9  wickets   236   won          v Sri
# 0        Sri    Lanka      lost 9  wickets   236  lost         v West
# 0    England      won     80 runs     lost  lost   1st        Zealand
# 0        New  Zealand     lost 80     runs  runs   won        England
# 0      India      won  10 wickets      181  lost   2nd    East Africa
# 0       East   Africa     lost 10  wickets   181   won        v India
# 0  Australia      won     52 runs     lost   1st     v      Lanka The
# 0        Sri    Lanka     lost 52     runs   won   2nd  Australia The
#
#          ground  date                                                url  \
# 0     Melbourne  1971  https://stats.espncricinfo.com/ci/engine/stats...
# 0     Melbourne  1971  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0        Lord's  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0        Lord's  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1972  https://stats.espncricinfo.com/ci/engine/stats...
# 0  Christchurch  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0  Christchurch  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Swansea  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Swansea  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1973  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Dunedin  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Dunedin  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0  Christchurch  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0  Christchurch  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Nottingham  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Nottingham  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1974  https://stats.espncricinfo.com/ci/engine/stats...
# 0     Melbourne  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0     Melbourne  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Dunedin  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0       Dunedin  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Wellington  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Wellington  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0        Lord's  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0        Lord's  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Birmingham  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Manchester  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Nottingham  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0    Nottingham  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0         Leeds  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1975  https://stats.espncricinfo.com/ci/engine/stats...
# 0          Oval  1975  https://stats.espncricinfo.com/ci/engine/stats...
#
#   scrapped_date
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12
# 0    2021-02-12

# %%
#cricdf = cric.cric_table

# %%
#cricdf.to_csv('cricket_data.csv', index = False)
